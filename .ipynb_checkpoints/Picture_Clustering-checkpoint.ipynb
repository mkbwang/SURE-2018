# %% [markdown]
# # Pixel Value Collection
# We want to take into account the darkness of the figures into account as well. Therefore we calculate the average RGB value of every figure for the experiment.

# %%
import pandas as pd
import numpy as np
from PIL import Image
import os

# %%
maindir = '/home/wangmk/UM/Research/SURE/ReconCustom/Picture_for_experiment/'

# %%
dirnames = os.listdir(maindir)

# %%
rgbdf = pd.DataFrame(columns=['R','G','B'])

# %%
for dirname in dirnames:
    pics = os.listdir(maindir+dirname)
    for pic in pics:
        print(pic)
        pic_fullname = maindir+dirname+'/'+pic
        img_file = Image.open(pic_fullname)
        img = img_file.load()
        [xs,ys] = img_file.size
        rgbsum = np.array([0,0,0])
        for x in range(xs):
            for y in range(ys):
                rgbsum += np.array(img[x,y][0:3])
        rgbdf.loc[pic] = rgbsum/(xs*ys)
# Out:
# OO_9_absent.png
# OO_20_absent.png
# OO_17_absent.png
# OO_19_absent.png
# OO_12_absent.png
# OO_8_absent.png
# OO_6_absent.png
# OO_13_absent.png
# OO_10_absent.png
# OO_15_absent.png
# OO_7_absent.png
# OO_4_absent.png
# OO_11_absent.png
# OO_5_absent.png
# OO_2_absent.png
# OO_16_absent.png
# OO_14_absent.png
# OO_3_absent.png
# OO_1_absent.png
# OO_18_absent.png
# PP_5_absent.png
# PP_12_absent.png
# PP_13_absent.png
# PP_2_absent.png
# PP_7_absent.png
# PP_14_absent.png
# PP_6_absent.png
# PP_11_absent.png
# PP_19_absent.png
# PP_3_absent.png
# PP_4_absent.png
# PP_9_absent.png
# PP_16_absent.png
# PP_18_absent.png
# PP_20_absent.png
# PP_10_absent.png
# PP_8_absent.png
# PP_17_absent.png
# PP_15_absent.png
# PP_1_absent.png
# FF_1_absent.png
# FF_2_absent.png
# FF_4_absent.png
# FF_20_absent.png
# FF_3_absent.png
# FF_19_absent.png
# FF_18_absent.png
# FF_17_absent.png
# FF_10_absent.png
# FF_5_absent.png
# FF_16_absent.png
# FF_9_absent.png
# FF_13_absent.png
# FF_15_absent.png
# FF_12_absent.png
# FF_11_absent.png
# FF_14_absent.png
# FF_6_absent.png
# FF_8_absent.png
# FF_7_absent.png
# HH_14_absentflip.png
# HH_11_absentflip.png
# HH_12_absentflip.png
# HH_16_absentflip.png
# HH_18_absentflip.png
# HH_17_absentflip.png
# HH_1_absentflip.png
# HH_6_absentflip.png
# HH_20_absentflip.png
# HH_7_absentflip.png
# HH_15_absentflip.png
# HH_8_absentflip.png
# HH_13_absentflip.png
# HH_10_absentflip.png
# HH_5_absentflip.png
# HH_3_absentflip.png
# HH_4_absentflip.png
# HH_19_absentflip.png
# HH_9_absentflip.png
# HH_2_absentflip.png
# CC_6_absentflip.png
# CC_14_absentflip.png
# CC_17_absentflip.png
# CC_12_absentflip.png
# CC_15_absentflip.png
# CC_1_absentflip.png
# CC_9_absentflip.png
# CC_11_absentflip.png
# CC_5_absentflip.png
# CC_10_absentflip.png
# CC_8_absentflip.png
# CC_13_absentflip.png
# CC_2_absentflip.png
# CC_20_absentflip.png
# CC_18_absentflip.png
# CC_4_absentflip.png
# CC_3_absentflip.png
# CC_16_absentflip.png
# CC_7_absentflip.png
# CC_19_absentflip.png
# TT_5_absent.png
# TT_17_absent.png
# TT_13_absent.png
# TT_20_absent.png
# TT_7_absent.png
# TT_12_absent.png
# TT_3_absent.png
# TT_8_absent.png
# TT_2_absent.png
# TT_9_absent.png
# TT_18_absent.png
# TT_1_absent.png
# TT_11_absent.png
# TT_15_absent.png
# TT_4_absent.png
# TT_19_absent.png
# TT_6_absent.png
# TT_14_absent.png
# TT_16_absent.png
# TT_10_absent.png
# GG_12_absentflip.png
# GG_4_absentflip.png
# GG_18_absentflip.png
# GG_11_absentflip.png
# GG_15_absentflip.png
# GG_8_absentflip.png
# GG_7_absentflip.png
# GG_13_absentflip.png
# GG_3_absentflip.png
# GG_2_absentflip.png
# GG_9_absentflip.png
# GG_19_absentflip.png
# GG_14_absentflip.png
# GG_16_absentflip.png
# GG_17_absentflip.png
# GG_20_absentflip.png
# GG_1_absentflip.png
# GG_5_absentflip.png
# GG_10_absentflip.png
# GG_6_absentflip.png
# EE_4_absentflip.png
# EE_6_absentflip.png
# EE_7_absentflip.png
# EE_11_absentflip.png
# EE_19_absentflip.png
# EE_1_absentflip.png
# EE_13_absentflip.png
# EE_15_absentflip.png
# EE_14_absentflip.png
# EE_8_absentflip.png
# EE_3_absentflip.png
# EE_5_absentflip.png
# EE_18_absentflip.png
# EE_2_absentflip.png
# EE_16_absentflip.png
# EE_10_absentflip.png
# EE_9_absentflip.png
# EE_20_absentflip.png
# EE_17_absentflip.png
# EE_12_absentflip.png
# AA_1_absentflip.png
# AA_16_absentflip.png
# AA_7_absentflip.png
# AA_14_absentflip.png
# AA_5_absentflip.png
# AA_3_absentflip.png
# AA_17_absentflip.png
# AA_6_absentflip.png
# AA_2_absentflip.png
# AA_4_absentflip.png
# AA_10_absentflip.png
# AA_11_absentflip.png
# AA_12_absentflip.png
# AA_18_absentflip.png
# AA_13_absentflip.png
# AA_9_absentflip.png
# AA_8_absentflip.png
# AA_15_absentflip.png
# AA_20_absentflip.png
# AA_19_absentflip.png
# NN_15_absentflip.png
# NN_11_absentflip.png
# NN_1_absentflip.png
# NN_7_absentflip.png
# NN_12_absentflip.png
# NN_19_absentflip.png
# NN_9_absentflip.png
# NN_20_absentflip.png
# NN_8_absentflip.png
# NN_2_absentflip.png
# NN_17_absentflip.png
# NN_5_absentflip.png
# NN_13_absentflip.png
# NN_6_absentflip.png
# NN_4_absentflip.png
# NN_10_absentflip.png
# NN_14_absentflip.png
# NN_3_absentflip.png
# NN_18_absentflip.png
# NN_16_absentflip.png
# OO_17_absentflip.png
# OO_13_absentflip.png
# OO_4_absentflip.png
# OO_5_absentflip.png
# OO_9_absentflip.png
# OO_7_absentflip.png
# OO_2_absentflip.png
# OO_18_absentflip.png
# OO_14_absentflip.png
# OO_11_absentflip.png
# OO_1_absentflip.png
# OO_8_absentflip.png
# OO_19_absentflip.png
# OO_16_absentflip.png
# OO_3_absentflip.png
# OO_12_absentflip.png
# OO_10_absentflip.png
# OO_20_absentflip.png
# OO_6_absentflip.png
# OO_15_absentflip.png
# BB_12_absent.png
# BB_14_absent.png
# BB_17_absent.png
# BB_15_absent.png
# BB_13_absent.png
# BB_19_absent.png
# BB_6_absent.png
# BB_1_absent.png
# BB_9_absent.png
# BB_2_absent.png
# BB_4_absent.png
# BB_8_absent.png
# BB_16_absent.png
# BB_10_absent.png
# BB_18_absent.png
# BB_7_absent.png
# BB_20_absent.png
# BB_11_absent.png
# BB_3_absent.png
# BB_5_absent.png
# AA_3_absent.png
# AA_1_absent.png
# AA_17_absent.png
# AA_18_absent.png
# AA_19_absent.png
# AA_16_absent.png
# AA_14_absent.png
# AA_7_absent.png
# AA_12_absent.png
# AA_20_absent.png
# AA_13_absent.png
# AA_2_absent.png
# AA_11_absent.png
# AA_10_absent.png
# AA_5_absent.png
# AA_15_absent.png
# AA_6_absent.png
# AA_9_absent.png
# AA_4_absent.png
# AA_8_absent.png
# SS_1_absentflip.png
# SS_3_absentflip.png
# SS_4_absentflip.png
# SS_7_absentflip.png
# SS_17_absentflip.png
# SS_11_absentflip.png
# SS_2_absentflip.png
# SS_20_absentflip.png
# SS_19_absentflip.png
# SS_13_absentflip.png
# SS_8_absentflip.png
# SS_9_absentflip.png
# SS_5_absentflip.png
# SS_14_absentflip.png
# SS_10_absentflip.png
# SS_12_absentflip.png
# SS_16_absentflip.png
# SS_18_absentflip.png
# SS_6_absentflip.png
# SS_15_absentflip.png
# GG_3_absent.png
# GG_18_absent.png
# GG_19_absent.png
# GG_17_absent.png
# GG_5_absent.png
# GG_4_absent.png
# GG_2_absent.png
# GG_1_absent.png
# GG_11_absent.png
# GG_20_absent.png
# GG_7_absent.png
# GG_15_absent.png
# GG_6_absent.png
# GG_14_absent.png
# GG_9_absent.png
# GG_16_absent.png
# GG_10_absent.png
# GG_12_absent.png
# GG_8_absent.png
# GG_13_absent.png
# QQ_1_absentflip.png
# QQ_8_absentflip.png
# QQ_9_absentflip.png
# QQ_7_absentflip.png
# QQ_4_absentflip.png
# QQ_3_absentflip.png
# QQ_11_absentflip.png
# QQ_6_absentflip.png
# QQ_16_absentflip.png
# QQ_20_absentflip.png
# QQ_19_absentflip.png
# QQ_2_absentflip.png
# QQ_12_absentflip.png
# QQ_15_absentflip.png
# QQ_10_absentflip.png
# QQ_5_absentflip.png
# QQ_17_absentflip.png
# QQ_18_absentflip.png
# QQ_13_absentflip.png
# QQ_14_absentflip.png
# LL_1_absent.png
# LL_8_absent.png
# LL_9_absent.png
# LL_16_absent.png
# LL_3_absent.png
# LL_10_absent.png
# LL_7_absent.png
# LL_20_absent.png
# LL_11_absent.png
# LL_6_absent.png
# LL_5_absent.png
# LL_4_absent.png
# LL_2_absent.png
# LL_17_absent.png
# LL_12_absent.png
# LL_13_absent.png
# LL_19_absent.png
# LL_18_absent.png
# LL_14_absent.png
# LL_15_absent.png
# MM_13_absentflip.png
# MM_7_absentflip.png
# MM_3_absentflip.png
# MM_4_absentflip.png
# MM_16_absentflip.png
# MM_14_absentflip.png
# MM_5_absentflip.png
# MM_9_absentflip.png
# MM_10_absentflip.png
# MM_11_absentflip.png
# MM_1_absentflip.png
# MM_6_absentflip.png
# MM_2_absentflip.png
# MM_15_absentflip.png
# MM_8_absentflip.png
# MM_17_absentflip.png
# MM_12_absentflip.png
# DD_12_absentflip.png
# DD_10_absentflip.png
# DD_5_absentflip.png
# DD_3_absentflip.png
# DD_9_absentflip.png
# DD_2_absentflip.png
# DD_18_absentflip.png
# DD_20_absentflip.png
# DD_19_absentflip.png
# DD_17_absentflip.png
# DD_15_absentflip.png
# DD_14_absentflip.png
# DD_4_absentflip.png
# DD_8_absentflip.png
# DD_11_absentflip.png
# DD_7_absentflip.png
# DD_1_absentflip.png
# DD_16_absentflip.png
# DD_13_absentflip.png
# DD_6_absentflip.png
# RR_1_absent.png
# RR_17_absent.png
# RR_15_absent.png
# RR_11_absent.png
# RR_14_absent.png
# RR_9_absent.png
# RR_3_absent.png
# RR_16_absent.png
# RR_19_absent.png
# RR_5_absent.png
# RR_4_absent.png
# RR_6_absent.png
# RR_7_absent.png
# RR_10_absent.png
# RR_18_absent.png
# RR_8_absent.png
# RR_13_absent.png
# RR_2_absent.png
# RR_12_absent.png
# SS_17_absent.png
# SS_9_absent.png
# SS_16_absent.png
# SS_10_absent.png
# SS_2_absent.png
# SS_1_absent.png
# SS_4_absent.png
# SS_7_absent.png
# SS_12_absent.png
# SS_6_absent.png
# SS_8_absent.png
# SS_20_absent.png
# SS_3_absent.png
# SS_19_absent.png
# SS_15_absent.png
# SS_18_absent.png
# SS_11_absent.png
# SS_13_absent.png
# SS_14_absent.png
# SS_5_absent.png
# RR_4_absentflip.png
# RR_9_absentflip.png
# RR_11_absentflip.png
# RR_8_absentflip.png
# RR_16_absentflip.png
# RR_17_absentflip.png
# RR_3_absentflip.png
# RR_1_absentflip.png
# RR_10_absentflip.png
# RR_5_absentflip.png
# RR_2_absentflip.png
# RR_15_absentflip.png
# RR_6_absentflip.png
# RR_19_absentflip.png
# RR_12_absentflip.png
# RR_14_absentflip.png
# RR_13_absentflip.png
# RR_18_absentflip.png
# RR_7_absentflip.png
# JJ_4_absent.png
# JJ_7_absent.png
# JJ_11_absent.png
# JJ_19_absent.png
# JJ_15_absent.png
# JJ_20_absent.png
# JJ_14_absent.png
# JJ_18_absent.png
# JJ_1_absent.png
# JJ_10_absent.png
# JJ_6_absent.png
# JJ_9_absent.png
# JJ_17_absent.png
# JJ_12_absent.png
# JJ_5_absent.png
# JJ_13_absent.png
# JJ_2_absent.png
# JJ_8_absent.png
# JJ_16_absent.png
# JJ_3_absent.png
# PP_14_absentflip.png
# PP_3_absentflip.png
# PP_16_absentflip.png
# PP_12_absentflip.png
# PP_19_absentflip.png
# PP_17_absentflip.png
# PP_11_absentflip.png
# PP_1_absentflip.png
# PP_4_absentflip.png
# PP_13_absentflip.png
# PP_18_absentflip.png
# PP_10_absentflip.png
# PP_2_absentflip.png
# PP_5_absentflip.png
# PP_8_absentflip.png
# PP_15_absentflip.png
# PP_7_absentflip.png
# PP_9_absentflip.png
# PP_6_absentflip.png
# PP_20_absentflip.png
# II_5_absent.png
# II_1_absent.png
# II_18_absent.png
# II_3_absent.png
# II_20_absent.png
# II_7_absent.png
# II_2_absent.png
# II_13_absent.png
# II_12_absent.png
# II_4_absent.png
# II_10_absent.png
# II_16_absent.png
# II_8_absent.png
# II_14_absent.png
# II_11_absent.png
# II_17_absent.png
# II_9_absent.png
# II_15_absent.png
# II_19_absent.png
# II_6_absent.png
# KK_19_absent.png
# KK_15_absent.png
# KK_7_absent.png
# KK_6_absent.png
# KK_14_absent.png
# KK_12_absent.png
# KK_2_absent.png
# KK_18_absent.png
# KK_8_absent.png
# KK_4_absent.png
# KK_11_absent.png
# KK_5_absent.png
# KK_17_absent.png
# KK_10_absent.png
# KK_16_absent.png
# KK_9_absent.png
# KK_13_absent.png
# KK_3_absent.png
# KK_1_absent.png
# KK_20_absent.png
# KK_13_absentflip.png
# KK_5_absentflip.png
# KK_1_absentflip.png
# KK_18_absentflip.png
# KK_15_absentflip.png
# KK_12_absentflip.png
# KK_16_absentflip.png
# KK_6_absentflip.png
# KK_8_absentflip.png
# KK_9_absentflip.png
# KK_11_absentflip.png
# KK_17_absentflip.png
# KK_2_absentflip.png
# KK_4_absentflip.png
# KK_14_absentflip.png
# KK_10_absentflip.png
# KK_7_absentflip.png
# KK_19_absentflip.png
# KK_3_absentflip.png
# KK_20_absentflip.png
# II_17_absentflip.png
# II_6_absentflip.png
# II_3_absentflip.png
# II_12_absentflip.png
# II_9_absentflip.png
# II_5_absentflip.png
# II_15_absentflip.png
# II_8_absentflip.png
# II_14_absentflip.png
# II_18_absentflip.png
# II_20_absentflip.png
# II_13_absentflip.png
# II_7_absentflip.png
# II_2_absentflip.png
# II_16_absentflip.png
# II_4_absentflip.png
# II_10_absentflip.png
# II_1_absentflip.png
# II_11_absentflip.png
# II_19_absentflip.png
# HH_19_absent.png
# HH_2_absent.png
# HH_10_absent.png
# HH_1_absent.png
# HH_8_absent.png
# HH_11_absent.png
# HH_4_absent.png
# HH_16_absent.png
# HH_6_absent.png
# HH_7_absent.png
# HH_13_absent.png
# HH_15_absent.png
# HH_14_absent.png
# HH_5_absent.png
# HH_17_absent.png
# HH_12_absent.png
# HH_3_absent.png
# HH_18_absent.png
# HH_20_absent.png
# HH_9_absent.png
# JJ_2_present.png
# CC_1_present.png
# TT_7_present.png
# TT_16_present.png
# KK_19_present.png
# HH_21_present.png
# GG_6_present.png
# TT_6_present.png
# FF_4_present.png
# FF_17_present.png
# LL_12_present.png
# EE_13_present.png
# FF_18_present.png
# SS_13_present.png
# KK_15_present.png
# EE_16_present.png
# II_2_present.png
# FF_13_present.png
# AA_12_present.png
# OO_10_present.png
# EE_5_present.png
# HH_14_present.png
# FF_11_present.png
# TT_13_present.png
# AA_8_present.png
# EE_10_present.png
# LL_6_present.png
# EE_14_present.png
# OO_6_present.png
# BB_1_present.png
# HH_13_present.png
# AA_5_present.png
# PP_7_present.png
# EE_6_present.png
# II_18_present.png
# FF_15_present.png
# KK_17_present.png
# SS_8_present.png
# SS_17_present.png
# GG_5_present.png
# OO_14_present.png
# SS_14_present.png
# NN_22_present.png
# SS_15_present.png
# GG_18_present.png
# JJ_5_present.png
# CC_4_present.png
# NN_20_present.png
# II_14_present.png
# KK_11_present.png
# SS_18_present.png
# GG_17_present.png
# FF_20_present.png
# JJ_6_present.png
# II_19_present.png
# CC_14_present.png
# NN_3_present.png
# NN_21_present.png
# LL_14_present.png
# FF_7_present.png
# TT_6_absentflip.png
# TT_12_absentflip.png
# TT_7_absentflip.png
# TT_13_absentflip.png
# TT_18_absentflip.png
# TT_17_absentflip.png
# TT_10_absentflip.png
# TT_16_absentflip.png
# TT_8_absentflip.png
# TT_9_absentflip.png
# TT_4_absentflip.png
# TT_20_absentflip.png
# TT_15_absentflip.png
# TT_1_absentflip.png
# TT_5_absentflip.png
# TT_3_absentflip.png
# TT_2_absentflip.png
# TT_19_absentflip.png
# TT_14_absentflip.png
# TT_11_absentflip.png
# FF_15_absentflip.png
# FF_18_absentflip.png
# FF_9_absentflip.png
# FF_8_absentflip.png
# FF_20_absentflip.png
# FF_16_absentflip.png
# FF_3_absentflip.png
# FF_7_absentflip.png
# FF_19_absentflip.png
# FF_2_absentflip.png
# FF_5_absentflip.png
# FF_4_absentflip.png
# FF_11_absentflip.png
# FF_10_absentflip.png
# FF_17_absentflip.png
# FF_12_absentflip.png
# FF_13_absentflip.png
# FF_6_absentflip.png
# FF_1_absentflip.png
# FF_14_absentflip.png
# NN_11_absent.png
# NN_10_absent.png
# NN_18_absent.png
# NN_7_absent.png
# NN_20_absent.png
# NN_5_absent.png
# NN_13_absent.png
# NN_9_absent.png
# NN_17_absent.png
# NN_3_absent.png
# NN_1_absent.png
# NN_8_absent.png
# NN_12_absent.png
# NN_19_absent.png
# NN_15_absent.png
# NN_4_absent.png
# NN_14_absent.png
# NN_16_absent.png
# NN_6_absent.png
# NN_2_absent.png
# CC_3_absent.png
# CC_19_absent.png
# CC_4_absent.png
# CC_15_absent.png
# CC_2_absent.png
# CC_13_absent.png
# CC_18_absent.png
# CC_5_absent.png
# CC_7_absent.png
# CC_14_absent.png
# CC_1_absent.png
# CC_12_absent.png
# CC_9_absent.png
# CC_17_absent.png
# CC_8_absent.png
# CC_10_absent.png
# CC_16_absent.png
# CC_20_absent.png
# CC_6_absent.png
# CC_11_absent.png
# BB_9_absentflip.png
# BB_18_absentflip.png
# BB_6_absentflip.png
# BB_11_absentflip.png
# BB_7_absentflip.png
# BB_2_absentflip.png
# BB_3_absentflip.png
# BB_10_absentflip.png
# BB_15_absentflip.png
# BB_19_absentflip.png
# BB_1_absentflip.png
# BB_4_absentflip.png
# BB_17_absentflip.png
# BB_16_absentflip.png
# BB_12_absentflip.png
# BB_14_absentflip.png
# BB_5_absentflip.png
# BB_20_absentflip.png
# BB_13_absentflip.png
# BB_8_absentflip.png
# EE_18_absent.png
# EE_4_absent.png
# EE_17_absent.png
# EE_14_absent.png
# EE_13_absent.png
# EE_9_absent.png
# EE_8_absent.png
# EE_12_absent.png
# EE_6_absent.png
# EE_19_absent.png
# EE_15_absent.png
# EE_10_absent.png
# EE_20_absent.png
# EE_11_absent.png
# EE_16_absent.png
# EE_1_absent.png
# EE_2_absent.png
# EE_5_absent.png
# EE_7_absent.png
# EE_3_absent.png
# DD_10_absent.png
# DD_20_absent.png
# DD_18_absent.png
# DD_5_absent.png
# DD_1_absent.png
# DD_6_absent.png
# DD_9_absent.png
# DD_7_absent.png
# DD_8_absent.png
# DD_12_absent.png
# DD_19_absent.png
# DD_17_absent.png
# DD_11_absent.png
# DD_13_absent.png
# DD_14_absent.png
# DD_15_absent.png
# DD_3_absent.png
# DD_2_absent.png
# DD_4_absent.png
# DD_16_absent.png
# JJ_14_absentflip.png
# JJ_5_absentflip.png
# JJ_15_absentflip.png
# JJ_4_absentflip.png
# JJ_3_absentflip.png
# JJ_8_absentflip.png
# JJ_11_absentflip.png
# JJ_13_absentflip.png
# JJ_7_absentflip.png
# JJ_16_absentflip.png
# JJ_12_absentflip.png
# JJ_1_absentflip.png
# JJ_2_absentflip.png
# JJ_6_absentflip.png
# JJ_18_absentflip.png
# JJ_17_absentflip.png
# JJ_9_absentflip.png
# JJ_10_absentflip.png
# JJ_20_absentflip.png
# JJ_19_absentflip.png
# MM_7_absent.png
# MM_16_absent.png
# MM_14_absent.png
# MM_6_absent.png
# MM_2_absent.png
# MM_10_absent.png
# MM_13_absent.png
# MM_4_absent.png
# MM_15_absent.png
# MM_11_absent.png
# MM_3_absent.png
# MM_17_absent.png
# MM_1_absent.png
# MM_9_absent.png
# MM_8_absent.png
# MM_12_absent.png
# MM_5_absent.png
# LL_11_absentflip.png
# LL_15_absentflip.png
# LL_10_absentflip.png
# LL_20_absentflip.png
# LL_9_absentflip.png
# LL_5_absentflip.png
# LL_8_absentflip.png
# LL_2_absentflip.png
# LL_4_absentflip.png
# LL_18_absentflip.png
# LL_6_absentflip.png
# LL_12_absentflip.png
# LL_3_absentflip.png
# LL_14_absentflip.png
# LL_1_absentflip.png
# LL_19_absentflip.png
# LL_17_absentflip.png
# LL_16_absentflip.png
# LL_7_absentflip.png
# LL_13_absentflip.png
# QQ_16_absent.png
# QQ_17_absent.png
# QQ_8_absent.png
# QQ_19_absent.png
# QQ_15_absent.png
# QQ_18_absent.png
# QQ_7_absent.png
# QQ_3_absent.png
# QQ_5_absent.png
# QQ_9_absent.png
# QQ_2_absent.png
# QQ_12_absent.png
# QQ_14_absent.png
# QQ_6_absent.png
# QQ_1_absent.png
# QQ_13_absent.png
# QQ_10_absent.png
# QQ_11_absent.png
# QQ_4_absent.png
# QQ_20_absent.png

# %%
rgbdf.to_csv("/home/wangmk/UM/Research/SURE/cleaned_data/RGB.csv")

# %% [markdown]
# # Picture Clustering
# CLuster pictures into dark and bright ones based on the pixel values we have got..

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %%
rgbdf = pd.read_csv("/home/wangmk/UM/Research/SURE/cleaned_data/RGB.csv",index_col=0)

# %%
rgbdf.head()
# Out:
#                           R          G          B
# OO_9_absent.png   61.399614  62.373057  60.786480
# OO_20_absent.png  57.225685  58.922975  60.769389
# OO_17_absent.png  16.440120  14.452102  12.232191
# OO_19_absent.png  43.077547  44.188059  46.495392
# OO_12_absent.png  67.352569  62.806281  64.548316

# %%
picnames = rgbdf.index.values

# %%
rgb_array = np.array(rgbdf)

# %%
rgb_array.shape
# Out:
# (852, 3)

# %%
kmeans = KMeans(n_clusters = 2)
kmeans.fit(rgb_array)
labels = kmeans.predict(rgb_array)

# %%
np.sum(labels)
# Out:
# 566

# %%
len(labels)
# Out:
# 852

# %%
pairs = dict(zip(picnames,labels))

# %%
import pickle

# %%
with open("/home/wangmk/UM/Research/SURE/cleaned_data/pic_brightness.pkl",'wb+') as f:
    pickle.dump([pairs],f)
